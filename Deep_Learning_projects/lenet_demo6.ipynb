# %%
import tensorflow
from tensorflow import keras
from keras.layers import Dense,Flatten,AveragePooling2D,Conv2D
from keras import Sequential
from keras.datasets import mnist

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model = Sequential()

model.add(Conv2D(6,kernel_size=(5,5),padding="valid",input_shape=(32,32,1),activation="tanh"))
model.add(AveragePooling2D(pool_size=(2,2),strides=2,padding="valid"))

model.add(Conv2D(16,kernel_size=(5,5),padding="valid",activation="tanh"))
model.add(AveragePooling2D(pool_size=(2,2),strides=2,padding="valid"))
model.add(Flatten())

model.add(Dense(120,activation="tanh"))
model.add(Dense(84,activation="tanh"))
model.add(Dense(10,activation="softmax"))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 28, 28, 6)           │             156 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_4                  │ (None, 14, 14, 6)           │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 10, 10, 16)          │           2,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# I recently implemented a convolutional neural network (CNN) inspired by the LeNet-5 architecture to classify handwritten digits from the MNIST dataset. Here's an overview of the project:

# What the Code Does
# This project focuses on implementing a CNN to classify handwritten digits (0–9) from grayscale images in the MNIST dataset. The model processes the input images through multiple layers, extracts meaningful features, and predicts the corresponding digit.

# Technologies/Tools Used
# TensorFlow/Keras: For designing and training the CNN architecture.
# Python: As the programming language for implementation.
# MNIST Dataset: A standard dataset of handwritten digits.
# Key Features of the Implementation
# Custom CNN Architecture:

# Convolutional Layers: Used Conv2D layers to extract spatial features with tanh activation.
# Average Pooling Layers: Incorporated AveragePooling2D layers to reduce spatial dimensions and computational load.
# Dense Layers: Fully connected layers to process the flattened feature maps for classification.
# Softmax Output Layer: For multi-class classification across 10 output categories (digits 0–9).
# Input Preparation:

# Extended MNIST images from (28x28) to (32x32) to align with the LeNet-5 architecture.
# Design Inspiration:

# The architecture follows the LeNet-5 model, which is a foundational design in the history of convolutional neural networks, highlighting the simplicity and effectiveness of early CNNs.
# Model Summary:

# Includes layer details like the number of filters, kernel size, activation functions, and parameter counts.
# Feedback and Interaction
# What do you think about leveraging classic architectures like LeNet-5 in modern machine learning workflows? Do you have suggestions for optimizing or enhancing the performance of this implementation? I’d love to hear your feedback or any tips for improving the model.

# Hashtags
# #ConvolutionalNeuralNetworks #DeepLearning #LeNet5 #TensorFlow #Keras #MachineLearning #MNIST #DataScience #Python #AI
